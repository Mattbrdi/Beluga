# %%
import numpy as np

# %%
DEPTH_T1 = 21.8-0.74 # Profondeur moins la hauteur des hydro 1, 2, 3 par rapport au bas du tétraèdre
COORDINATES_T1 = [47.9398522060365, -69.5222868584096, -DEPTH_T1] 

ARRAY_LENGTH_1 = .3 # Longueur des arretes en mètres
# Coordonnées des sommets du tétraèdre dans le référentiel défini DANS LE MEME ORDRE QUE LES CANAUX D'ENREGISTREMENT
COORDINATES_HYDROPHONES_1 = np.array([
    [np.sqrt(3)*ARRAY_LENGTH_1/3, 0, 0], # Canal 1
    [-np.sqrt(3)*ARRAY_LENGTH_1/6, -ARRAY_LENGTH_1/2, 0], # Canal 2
    [-np.sqrt(3)*ARRAY_LENGTH_1/6, ARRAY_LENGTH_1/2, 0], # Canal 3
    [0, 0, np.sqrt(6)*ARRAY_LENGTH_1/3] # Canal 4
])
print("coordiante lla : ", COORDINATES_T1)
print(COORDINATES_HYDROPHONES_1)
# Out:
# coordiante lla :  [47.9398522060365, -69.5222868584096, -21.060000000000002]
# [[ 0.17320508  0.          0.        ]
#  [-0.08660254 -0.15        0.        ]
#  [-0.08660254  0.15        0.        ]
#  [ 0.          0.          0.24494897]]

# %%
# Matrice de rotation:
[[ 0.24979828  ,0.96612488,  -0.06483474], 
 [-0.96228928 , 0.24024339, -0.12760275], 
 [-0.10770408 , 0.09426472 , 0.98970399]]
# Out:
# [[0.24979828, 0.96612488, -0.06483474],
#  [-0.96228928, 0.24024339, -0.12760275],
#  [-0.10770408, 0.09426472, 0.98970399]]

# %%
DEPTH_T2 = 21.2-0.74 # Profondeur moins la hauteur des hydro 1, 2, 3 par rapport au bas du tétraèdre
COORDINATES_T2 = [47.9429208207876, -69.5185261499137, -DEPTH_T2]

ARRAY_LENGTH_2 = .3 
COORDINATES_HYDROPHONES_2 = np.array([ # DANS LE MEME ORDRE QUE LES CANAUX D'ENREGISTREMENT
    [np.sqrt(3)*ARRAY_LENGTH_2/3, 0, 0], # Canal 1
    [-np.sqrt(3)*ARRAY_LENGTH_2/6, -ARRAY_LENGTH_2/2, 0], # Canal 2
    [-np.sqrt(3)*ARRAY_LENGTH_2/6, ARRAY_LENGTH_2/2, 0], # Canal 3
    [0, 0, np.sqrt(6)*ARRAY_LENGTH_2/3] # Canal 4
])
print("coodinate lla : ", COORDINATES_T2)
print(COORDINATES_HYDROPHONES_2)
# Out:
# coodinate lla :  [47.9429208207876, -69.5185261499137, -20.46]
# [[ 0.17320508  0.          0.        ]
#  [-0.08660254 -0.15        0.        ]
#  [-0.08660254  0.15        0.        ]
#  [ 0.          0.          0.24494897]]

# %%
#matrice de rotation
[[ 0.17662491 , 0.79289067 , 0.58320497],
 [ 0.31625516 , -0.60681804 , 0.72921502],
 [ 0.93208707 , 0.05564404, -0.35793495]]
# Out:
# [[0.17662491, 0.79289067, 0.58320497],
#  [0.31625516, -0.60681804, 0.72921502],
#  [0.93208707, 0.05564404, -0.35793495]]
