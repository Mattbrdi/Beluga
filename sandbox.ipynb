# %%
from BSS.Utils.signal_generation.signals import WhistleSignal, LargeShipNoise
from numpy.random import default_rng
rng = default_rng()
sig = WhistleSignal.generate_random(rng = rng, freq=300000,time_duration = 2.0)
sig = LargeShipNoise.generate_random(rng = rng, freq = 300000, time_duration = 2.0)

# %%
import matplotlib.pyplot as plt 
a, b, c = sig.plot_with_sounds()
d, e = sig.plot_spectrogram(nperseg = 4098, noverlap=2048)
plt.show()
